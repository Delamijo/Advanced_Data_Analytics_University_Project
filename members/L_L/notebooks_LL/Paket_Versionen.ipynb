# %% [markdown]
# # Paket Versionen

# %%
import numpy
import pandas
import scipy
import sklearn
import xgboost
import catboost
import optuna
import optuna_integration
import joblib
import matplotlib
import seaborn

# %%
print("numpy", numpy.__version__)
print("pandas", pandas.__version__)
print("scipy", scipy.__version__)
print("scikit-learn", sklearn.__version__)
print("xgboost", xgboost.__version__)
print("catboost", catboost.__version__)
print("optuna", optuna.__version__)
print("optuna-integration", optuna_integration.__version__)
print("joblib", joblib.__version__)
print("matplotlib", matplotlib.__version__)
print("seaborn", seaborn.__version__)
# Out:
# numpy 1.26.4
# pandas 3.0.3
# scipy 1.17.1
# scikit-learn 1.9.0
# xgboost 3.2.0
# catboost 1.2.10
# optuna 4.9.0
# optuna-integration 4.9.0
# joblib 1.5.3
# matplotlib 3.11.0
# seaborn 0.13.2

# %%
versionen_L = {
    "numpy": "1.26.4",
    "pandas": "3.0.3",
    "scipy": "1.17.1",
    "scikit-learn": "1.9.0",
    "xgboost": "3.2.0",
    "catboost": "1.2.10",
    "optuna": "4.9.0",
    "optuna-integration": "4.9.0",
    "joblib": "1.5.3",
    "matplotlib": "3.11.0",
    "seaborn": "0.13.2",
}

versionen_hier = {
    "numpy": numpy.__version__,
    "pandas": pandas.__version__,
    "scipy": scipy.__version__,
    "scikit-learn": sklearn.__version__,
    "xgboost": xgboost.__version__,
    "catboost": catboost.__version__,
    "optuna": optuna.__version__,
    "optuna-integration": optuna_integration.__version__,
    "joblib": joblib.__version__,
    "matplotlib": matplotlib.__version__,
    "seaborn": seaborn.__version__,
}

df_versionen = pandas.DataFrame({
    "L_L": pandas.Series(versionen_L),
    "new": pandas.Series(versionen_hier),
})
df_versionen["identisch"] = df_versionen["L_L"] == df_versionen["new"]
df_versionen.index.name = "paket"

df_versionen
# Out:
#                        L_L     new  identisch
# paket
# numpy               1.26.4  1.26.4       True
# pandas               3.0.3   3.0.3       True
# scipy               1.17.1  1.17.1       True
# scikit-learn         1.9.0   1.9.0       True
# xgboost              3.2.0   3.2.0       True
# catboost            1.2.10  1.2.10       True
# optuna               4.9.0   4.9.0       True
# optuna-integration   4.9.0   4.9.0       True
# joblib               1.5.3   1.5.3       True
# matplotlib          3.11.0  3.11.0       True
# seaborn             0.13.2  0.13.2       True
